# %%
print(10+8) #addition
print(10-8) #subtraction
# Out:
# 18
# 2

# %%
print(2 * 3) #multiply 
print(15/5) #divison
print(15 // 5) #floor divison
# Out:
# 6
# 3.0
# 3

# %%
print(10%2) #remainder
print(2 ** 3) #exponent
# Out:
# 0
# 8

# %%
print(5 == 5) #equality 
print(7!=5) #inequality
print(5>3) #greater than
print(3<4) #lesser than
# Out:
# True
# True
# True
# True

# %%
print(True and False)
print(True or False)
print(not True)
# Out:
# False
# True
# False

# %%
x=10
print(x)
x += 5
print(x)
x -= 5
print(x)
x *= 5
print(5)
x /= 10
print(x)
# Out:
# 10
# 15
# 10
# 5
# 5.0
