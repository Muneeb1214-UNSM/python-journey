# %%
age = "24"

# %%
type(age)
# Out:
# str

# %%
print(age)
# Out:
# 24

# %%
print(int(age)+1)
# Out:
# 25

# %%
age=input("please write your age")
# Out:
# please write your age 25

# %%
type(age)
# Out:
# str

# %%
myage = int(age)

# %%
type(myage)
# Out:
# int
