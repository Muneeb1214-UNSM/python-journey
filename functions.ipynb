# %%
def greet():
    print("hello world")

greet()
# Out:
# hello world

# %%
def greet(name):
    print("hello", name)

greet("ali")
greet("sara")
# Out:
# hello ali
# hello sara

# %%
def add(a,b):
    return a+b

# %%
result = add(1,5)
print(result)
# Out:
# 6

# %%
def square(num):
    return num * num

# %%
result = square(6)
print(result)
# Out:
# 36
