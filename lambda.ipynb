# %%
add = lambda a,b : a+b

# %%
print(add(3,5))
# Out:
# 8

# %%
double_num = lambda n:n * 2

# %%
print(double_num(5))
# Out:
# 10

# %%
nums = [1,2,3,4]
squares = list(map(lambda x:x * x,nums))

# %%
print(squares)
# Out:
# [1, 4, 9, 16]

# %%
numb = [1,2,3,4,5,6,7,8]
odd_num = list(filter(lambda x: x % 2 != 0, numb))

# %%
print(odd_num)
# Out:
# [1, 3, 5, 7]
