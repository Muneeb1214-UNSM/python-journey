# %%
for i in range(3):
    print("python is fun")
# Out:
# python is fun
# python is fun
# python is fun

# %%
for char in "python":
    print(char)
# Out:
# p
# y
# t
# h
# o
# n

# %%
count = 1
while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(3):
    print(" outer loop ")
    for j in range(3):
        print("          inner loop     ")
# Out:
#  outer loop
#           inner loop
#           inner loop
#           inner loop
#  outer loop
#           inner loop
#           inner loop
#           inner loop
#  outer loop
#           inner loop
#           inner loop
#           inner loop
